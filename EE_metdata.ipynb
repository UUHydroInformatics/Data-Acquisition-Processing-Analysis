# %% [markdown]
# ![HydroCycle](images/hydro_5cycle.jpg)
#
# # Retrieve and Analyze Hydrology data for a watershed of interest
#
# To make predictions for reservoir operations, water supply, flood control, etc, we need to collect data to train/calibrate hydrologic models. This includes streamflow, current environmental conditions (e.g., snow water equivalent), and future weather predictions. This exercise will build on the previous SNOTEL module to work towards building a hydrologic module.
#
# Need to find a station? Use the [USGS NWIS mapper system](https://apps.usgs.gov/nwismapper/)
#
#
# Click the link and explore!

# %% [markdown]
# # 1. Delineated Watershed Map Upstream of a NWIS Site
# The following code uses the pynhd and folium packages to create an interactive map of a watershed from a USGS gauge ID.
#
# In our exercise, we are tasked with identifying all SNOTEL sites upstream of Hetch Hetchy Reservoir on the Tuolumne River. The user can search for "USGS streamflow Tuolumne River" and serveral locations will pop up. Site [11274790](https://waterdata.usgs.gov/monitoring-location/11274790/#dataTypeId=continuous-00065-0&period=P7D&showMedian=false) is the site of interest for this assessment

# %%
from pynhd import NLDI, WaterData, NHDPlusHR, GeoConnex
import geopandas as gpd
import pandas as pd
from supporting_scripts import getData, SNOTEL_Analyzer, dataprocessing, mapping
from shapely.geometry import box, Polygon
import os
import datetime
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Define the watershed outlet using NWIS site id. Create a map object that we'll add layers to.

# %%
nldi = NLDI()
usgs_gage_id = "11274790" # NWIS id for Tuolumne river at the mouth of Hetch Hetchy Reservoir
WY = 2019 # Water Year to analyze. A water year is defined as the 12 month period from October 1st to September 30th.

# %% [markdown]
# ## Get meterological information data for our area of interest using GEE and NLDAS2
#
# We will be using the GEE python api to retrived NLDAS2 meteorological data from the [NLDAS Earth Engine Catalog](https://developers.google.com/earth-engine/datasets/catalog/NASA_NLDAS_FORA0125_H002).
#
# ![GEE_NLDAS](images/NASA_NLDAS_FORA0125_H002_sample.png)

# %%
# Get geometry and ensure CRS is correct
basin = NLDI().get_basins(usgs_gage_id)

if basin is None or basin.empty:
    raise ValueError(f"No basin returned for USGS site {usgs_gage_id}")

geometry = basin.to_crs("EPSG:4326").geometry.iloc[0]
basin_polygon_coords = list(geometry.exterior.coords)

# %%
import sys
# !{sys.executable} -m pip install earthengine-api
# Out:
# Requirement already satisfied: earthengine-api in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (1.7.18)
# Requirement already satisfied: google-cloud-storage in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from earthengine-api) (3.10.1)
# Requirement already satisfied: google-api-python-client>=1.12.1 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from earthengine-api) (2.193.0)
# Requirement already satisfied: google-auth>=1.4.1 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from earthengine-api) (2.49.1)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from earthengine-api) (0.3.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from earthengine-api) (0.31.2)
# Requirement already satisfied: requests in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from earthengine-api) (2.32.5)
# Requirement already satisfied: pyparsing<4,>=3.1 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from httplib2<1dev,>=0.9.2->earthengine-api) (3.3.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from google-api-python-client>=1.12.1->earthengine-api) (2.30.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from google-api-python-client>=1.12.1->earthengine-api) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.3 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.73.0)
# Requirement already satisfied: protobuf<7.0.0,>=4.25.8 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (6.33.6)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.27.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from google-auth>=1.4.1->earthengine-api) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from google-auth>=1.4.1->earthengine-api) (46.0.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from requests->earthengine-api) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from requests->earthengine-api) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from requests->earthengine-api) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from requests->earthengine-api) (2026.2.25)
# Requirement already satisfied: cffi>=2.0.0 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from cryptography>=38.0.3->google-auth>=1.4.1->earthengine-api) (2.0.0)
# Requirement already satisfied: pycparser in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth>=1.4.1->earthengine-api) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api) (0.6.3)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from google-cloud-storage->earthengine-api) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from google-cloud-storage->earthengine-api) (2.8.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from google-cloud-storage->earthengine-api) (1.8.0)

# %%
import ee
ee.Initialize()
print("EE working")
# Out:
# EE working

# %%
#we can get hourly data  but it can take a long time and crash if the start and end date are too far apart
hourly_NLDAS_df = getData.get_NLDAS_hourly(basin_polygon_coords)
hourly_NLDAS_df.head()
# Out:
# Authenticating with Earth Engine...
# Initializing Earth Engine...
# Earth Engine initialized successfully.
#                      convective_fraction  longwave_radiation  \
# Date
# 2025-12-30T00:00:00                    0          172.669593
# 2025-12-30T01:00:00                    0          172.661561
# 2025-12-30T02:00:00                    0          172.647718
# 2025-12-30T03:00:00                    0          173.021182
# 2025-12-30T04:00:00                    0          173.022314
#
#                      potential_energy  potential_evaporation      pressure  \
# Date
# 2025-12-30T00:00:00                 0               0.121580  72526.931766
# 2025-12-30T01:00:00                 0               0.015232  72528.440877
# 2025-12-30T02:00:00                 0               0.015232  72529.957224
# 2025-12-30T03:00:00                 0               0.015232  72531.429234
# 2025-12-30T04:00:00                 0               0.015069  72517.665395
#
#                      shortwave_radiation  specific_humidity  temperature  \
# Date
# 2025-12-30T00:00:00            74.186356           0.001754    -1.542932
# 2025-12-30T01:00:00             0.000000           0.001446    -2.025731
# 2025-12-30T02:00:00             0.000000           0.001137    -2.507450
# 2025-12-30T03:00:00             0.000000           0.000829    -2.990934
# 2025-12-30T04:00:00             0.000000           0.000801    -2.885945
#
#                      total_precipitation    wind_u    wind_v
# Date
# 2025-12-30T00:00:00                  0.0 -3.768520 -0.331718
# 2025-12-30T01:00:00                  0.0 -3.886196 -0.412349
# 2025-12-30T02:00:00                  0.0 -4.004585 -0.493898
# 2025-12-30T03:00:00                  0.0 -4.119638 -0.571880
# 2025-12-30T04:00:00                  0.0 -4.053641 -0.270350

# %%
import importlib
importlib.reload(getData)
# Out:
# <module 'supporting_scripts.getData' from '/uufs/chpc.utah.edu/common/home/u1257442/Data-Acquisition-Processing-Analysis/supporting_scripts/getData.py'>

# %%
#It crashes if we try to get too much data at once, so we will get daily data for a smaller range of dates
Daily_NLDAS_df = getData.get_NLDAS_daily(basin_polygon_coords, begin_date='2006-01-01', end_date='2012-01-1')
Daily_NLDAS_df.head()
# Out:
# Authenticating with Earth Engine...
# Initializing Earth Engine...
# Earth Engine initialized successfully.
#             convective_fraction  longwave_radiation  potential_energy  \
# Date
# 2006-01-01             0.005192          199.833836          1.508087
# 2006-01-02             0.051767          264.132482         33.055034
# 2006-01-03             0.016707          214.292827          9.209950
# 2006-01-04             0.000000          226.581243          0.000000
# 2006-01-05             0.000000          214.910143          0.000000
#
#             potential_evaporation      pressure  shortwave_radiation  \
# Date
# 2006-01-01               0.044990  71408.170160            95.234192
# 2006-01-02               0.013663  70799.285724            93.932771
# 2006-01-03               0.030093  71724.799553           101.167170
# 2006-01-04               0.016272  72808.304958           101.368610
# 2006-01-05               0.033974  73429.441947           112.546583
#
#             specific_humidity  temperature  total_precipitation    wind_u  \
# Date
# 2006-01-01           0.002439    -7.561317             0.563703  2.807882
# 2006-01-02           0.004772    -0.944478             4.532128  4.467674
# 2006-01-03           0.002966    -6.371842             0.575387  4.247262
# 2006-01-04           0.003240    -3.462835             0.002358  1.485389
# 2006-01-05           0.002849     1.320337             0.000000 -0.779809
#
#               wind_v
# Date
# 2006-01-01  5.710911
# 2006-01-02  8.864378
# 2006-01-03  3.778855
# 2006-01-04  1.450410
# 2006-01-05  3.417216

# %%
#It crashes if we try to get too much data at once, so we will get daily data for a smaller range of dates
Daily_NLDAS_df_2 = getData.get_NLDAS_daily(basin_polygon_coords, begin_date='2012-01-1', end_date='2018-01-1')
Daily_NLDAS_df_2.head()
# Out:
# Authenticating with Earth Engine...
# Initializing Earth Engine...
# Earth Engine initialized successfully.
#             convective_fraction  longwave_radiation  potential_energy  \
# Date
# 2012-01-01                  0.0          189.961892               0.0
# 2012-01-02                  0.0          182.659036               0.0
# 2012-01-03                  0.0          186.784356               0.0
# 2012-01-04                  0.0          203.650393               0.0
# 2012-01-05                  0.0          199.040962               0.0
#
#             potential_evaporation      pressure  shortwave_radiation  \
# Date
# 2012-01-01               0.020069  72932.843593           115.136221
# 2012-01-02               0.074016  72938.497667           114.566230
# 2012-01-03               0.057585  73102.016670           115.180582
# 2012-01-04               0.016956  73281.697993           114.207124
# 2012-01-05               0.019039  73114.227991           115.751271
#
#             specific_humidity  temperature  total_precipitation    wind_u  \
# Date
# 2012-01-01           0.002084    -0.202470                  0.0 -0.991600
# 2012-01-02           0.001812    -0.135426                  0.0  0.471567
# 2012-01-03           0.001867    -0.252943                  0.0  0.908515
# 2012-01-04           0.002370     1.254940                  0.0  0.281917
# 2012-01-05           0.002468     0.890008                  0.0  0.547861
#
#               wind_v
# Date
# 2012-01-01  2.050845
# 2012-01-02  4.762250
# 2012-01-03  3.012314
# 2012-01-04  2.012439
# 2012-01-05  0.219101

# %%
#It crashes if we try to get too much data at once, so we will get daily data for a smaller range of dates
Daily_NLDAS_df_3 = getData.get_NLDAS_daily(basin_polygon_coords, begin_date='2018-01-1', end_date='2022-01-1')
Daily_NLDAS_df_3.head()
# Out:
# Authenticating with Earth Engine...
# Initializing Earth Engine...
# Earth Engine initialized successfully.
#             convective_fraction  longwave_radiation  potential_energy  \
# Date
# 2018-01-01             0.000000          213.800975          0.000000
# 2018-01-02             0.000000          204.065878          0.000000
# 2018-01-03             0.000000          223.960795          0.000000
# 2018-01-04             0.000000          260.845301          0.000000
# 2018-01-05             0.000321          219.271025          0.038969
#
#             potential_evaporation      pressure  shortwave_radiation  \
# Date
# 2018-01-01               0.043056  72743.806196           108.580816
# 2018-01-02               0.014744  72883.815261           108.682097
# 2018-01-03               0.043999  72643.889605           104.670993
# 2018-01-04               0.016014  72416.805059           100.806345
# 2018-01-05               0.023548  72473.213601            97.696687
#
#             specific_humidity  temperature  total_precipitation    wind_u  \
# Date
# 2018-01-01           0.002056     0.237548             0.000000  0.364702
# 2018-01-02           0.002514     0.174304             0.000000 -1.076387
# 2018-01-03           0.002524     0.519115             0.000000 -0.218272
# 2018-01-04           0.004571     0.430183             0.081611  0.572277
# 2018-01-05           0.003904    -1.310952             0.012962  1.340124
#
#               wind_v
# Date
# 2018-01-01  1.898353
# 2018-01-02  1.537924
# 2018-01-03  3.318727
# 2018-01-04  4.713699
# 2018-01-05  4.438616

# %%
#combine the three dataframes into one
Daily_NLDAS_df = pd.concat([Daily_NLDAS_df, Daily_NLDAS_df_2, Daily_NLDAS_df_3], ignore_index=True)
#set 
Daily_NLDAS_df.head()
# Out:
#    convective_fraction  longwave_radiation  potential_energy  \
# 0             0.005192          199.833836          1.508087
# 1             0.051767          264.132482         33.055034
# 2             0.016707          214.292827          9.209950
# 3             0.000000          226.581243          0.000000
# 4             0.000000          214.910143          0.000000
#
#    potential_evaporation      pressure  shortwave_radiation  \
# 0               0.044990  71408.170160            95.234192
# 1               0.013663  70799.285724            93.932771
# 2               0.030093  71724.799553           101.167170
# 3               0.016272  72808.304958           101.368610
# 4               0.033974  73429.441947           112.546583
#
#    specific_humidity  temperature  total_precipitation    wind_u    wind_v
# 0           0.002439    -7.561317             0.563703  2.807882  5.710911
# 1           0.004772    -0.944478             4.532128  4.467674  8.864378
# 2           0.002966    -6.371842             0.575387  4.247262  3.778855
# 3           0.003240    -3.462835             0.002358  1.485389  1.450410
# 4           0.002849     1.320337             0.000000 -0.779809  3.417216

# %%
Daily_NLDAS_df.tail()
# Out:
#       convective_fraction  longwave_radiation  potential_energy  \
# 5839             0.018223          219.984779          7.729698
# 5840             0.002725          214.808744          0.018763
# 5841             0.000412          205.754843          1.239420
# 5842             0.000000          178.973635          0.246624
# 5843             0.000000          178.731055          0.000000
#
#       potential_evaporation      pressure  shortwave_radiation  \
# 5839               0.026481  71003.241333            65.660055
# 5840               0.019029  70766.391160            66.984720
# 5841               0.013572  70737.086034            67.270818
# 5842               0.012914  71102.204130           111.694618
# 5843               0.032721  71057.141310           112.494972
#
#       specific_humidity  temperature  total_precipitation    wind_u    wind_v
# 5839           0.001950   -11.505627             0.725131  6.359012  6.717583
# 5840           0.001898   -11.786303             0.046239  4.240648  2.041985
# 5841           0.001965   -11.617362             0.190203  1.939715  4.258089
# 5842           0.002160    -9.993520             0.067344  1.640725  3.325037
# 5843           0.002094    -8.306853             0.000092  5.121601  1.422705

# %% [markdown]
# ## Data exploration
#
# ### Lets examine basin longwave and shortwave radiation

# %%
print(Daily_NLDAS_df.head())
print(Daily_NLDAS_df.index)
print(type(Daily_NLDAS_df.index))
# Out:
#    convective_fraction  longwave_radiation  potential_energy  \
# 0             0.005192          199.833836          1.508087
# 1             0.051767          264.132482         33.055034
# 2             0.016707          214.292827          9.209950
# 3             0.000000          226.581243          0.000000
# 4             0.000000          214.910143          0.000000
#
#    potential_evaporation      pressure  shortwave_radiation  \
# 0               0.044990  71408.170160            95.234192
# 1               0.013663  70799.285724            93.932771
# 2               0.030093  71724.799553           101.167170
# 3               0.016272  72808.304958           101.368610
# 4               0.033974  73429.441947           112.546583
#
#    specific_humidity  temperature  total_precipitation    wind_u    wind_v
# 0           0.002439    -7.561317             0.563703  2.807882  5.710911
# 1           0.004772    -0.944478             4.532128  4.467674  8.864378
# 2           0.002966    -6.371842             0.575387  4.247262  3.778855
# 3           0.003240    -3.462835             0.002358  1.485389  1.450410
# 4           0.002849     1.320337             0.000000 -0.779809  3.417216
# RangeIndex(start=0, stop=5844, step=1)
# <class 'pandas.RangeIndex'>

# %%
print(Daily_NLDAS_df.columns)
print(Daily_NLDAS_df_2.columns)
print(Daily_NLDAS_df_3.columns)
# Out:
# Index(['convective_fraction', 'longwave_radiation', 'potential_energy',
#        'potential_evaporation', 'pressure', 'shortwave_radiation',
#        'specific_humidity', 'temperature', 'total_precipitation', 'wind_u',
#        'wind_v'],
#       dtype='str')
# Index(['convective_fraction', 'longwave_radiation', 'potential_energy',
#        'potential_evaporation', 'pressure', 'shortwave_radiation',
#        'specific_humidity', 'temperature', 'total_precipitation', 'wind_u',
#        'wind_v'],
#       dtype='str')
# Index(['convective_fraction', 'longwave_radiation', 'potential_energy',
#        'potential_evaporation', 'pressure', 'shortwave_radiation',
#        'specific_humidity', 'temperature', 'total_precipitation', 'wind_u',
#        'wind_v'],
#       dtype='str')

# %%
Daily_NLDAS_df = getData.get_NLDAS_daily(basin_polygon_coords, begin_date='2006-01-01', end_date='2012-01-01')
Daily_NLDAS_df_2 = getData.get_NLDAS_daily(basin_polygon_coords, begin_date='2012-01-01', end_date='2018-01-01')
Daily_NLDAS_df_3 = getData.get_NLDAS_daily(basin_polygon_coords, begin_date='2018-01-01', end_date='2022-01-01')
# Out:
# Authenticating with Earth Engine...
# Initializing Earth Engine...
# Earth Engine initialized successfully.
# Authenticating with Earth Engine...
# Initializing Earth Engine...
# Earth Engine initialized successfully.
# Authenticating with Earth Engine...
# Initializing Earth Engine...
# Earth Engine initialized successfully.

# %%
print(Daily_NLDAS_df.columns)
print(Daily_NLDAS_df_2.columns)
print(Daily_NLDAS_df_3.columns)
# Out:
# Index(['convective_fraction', 'longwave_radiation', 'potential_energy',
#        'potential_evaporation', 'pressure', 'shortwave_radiation',
#        'specific_humidity', 'temperature', 'total_precipitation', 'wind_u',
#        'wind_v'],
#       dtype='str')
# Index(['convective_fraction', 'longwave_radiation', 'potential_energy',
#        'potential_evaporation', 'pressure', 'shortwave_radiation',
#        'specific_humidity', 'temperature', 'total_precipitation', 'wind_u',
#        'wind_v'],
#       dtype='str')
# Index(['convective_fraction', 'longwave_radiation', 'potential_energy',
#        'potential_evaporation', 'pressure', 'shortwave_radiation',
#        'specific_humidity', 'temperature', 'total_precipitation', 'wind_u',
#        'wind_v'],
#       dtype='str')

# %%
Daily_NLDAS_all = pd.concat([Daily_NLDAS_df, Daily_NLDAS_df_2, Daily_NLDAS_df_3], ignore_index=True)

# %%
print(Daily_NLDAS_all.columns)
print(Daily_NLDAS_all.index)
print(Daily_NLDAS_all.index.name)
# Out:
# Index(['convective_fraction', 'longwave_radiation', 'potential_energy',
#        'potential_evaporation', 'pressure', 'shortwave_radiation',
#        'specific_humidity', 'temperature', 'total_precipitation', 'wind_u',
#        'wind_v'],
#       dtype='str')
# RangeIndex(start=0, stop=5844, step=1)
# None

# %%
# if date is already the index
if 'date' not in Daily_NLDAS_all.columns:
    Daily_NLDAS_all.index = pd.to_datetime(Daily_NLDAS_all.index)
    Daily_NLDAS_all = Daily_NLDAS_all.sort_index()
else:
    Daily_NLDAS_all['date'] = pd.to_datetime(Daily_NLDAS_all['date'])
    Daily_NLDAS_all = Daily_NLDAS_all.sort_values('date').set_index('date')

# %%
met_df_2019 = Daily_NLDAS_all.loc['2018-10-01':'2019-09-30'].copy()

print(met_df_2019.shape)
print(met_df_2019.head())
# Out:
# (0, 11)
# Empty DataFrame
# Columns: [convective_fraction, longwave_radiation, potential_energy, potential_evaporation, pressure, shortwave_radiation, specific_humidity, temperature, total_precipitation, wind_u, wind_v]
# Index: []

# %%
print(met_df_2019.shape)
print(met_df_2019.index.min(), met_df_2019.index.max())
print(met_df_2019[['longwave_radiation', 'shortwave_radiation']].head())
print(met_df_2019[['longwave_radiation', 'shortwave_radiation']].describe())
# Out:
# (0, 11)
# NaT NaT
# Empty DataFrame
# Columns: [longwave_radiation, shortwave_radiation]
# Index: []
#        longwave_radiation  shortwave_radiation
# count                 0.0                  0.0
# mean                  NaN                  NaN
# std                   NaN                  NaN
# min                   NaN                  NaN
# 25%                   NaN                  NaN
# 50%                   NaN                  NaN
# 75%                   NaN                  NaN
# max                   NaN                  NaN

# %%
Daily_NLDAS_df = getData.get_NLDAS_daily(basin_polygon_coords, begin_date='2006-01-01', end_date='2012-01-01')
Daily_NLDAS_df_2 = getData.get_NLDAS_daily(basin_polygon_coords, begin_date='2012-01-01', end_date='2018-01-01')
Daily_NLDAS_df_3 = getData.get_NLDAS_daily(basin_polygon_coords, begin_date='2018-01-01', end_date='2022-01-01')
# Out:
# Authenticating with Earth Engine...
# Initializing Earth Engine...
# Earth Engine initialized successfully.
# Authenticating with Earth Engine...
# Initializing Earth Engine...
# Earth Engine initialized successfully.
# Authenticating with Earth Engine...
# Initializing Earth Engine...
# Earth Engine initialized successfully.

# %%
print(Daily_NLDAS_df.head())
print(Daily_NLDAS_df.columns)
print(Daily_NLDAS_df_2.columns)
print(Daily_NLDAS_df_3.columns)
# Out:
#             convective_fraction  longwave_radiation  potential_energy  \
# Date
# 2006-01-01             0.005192          199.833836          1.508087
# 2006-01-02             0.051767          264.132482         33.055034
# 2006-01-03             0.016707          214.292827          9.209950
# 2006-01-04             0.000000          226.581243          0.000000
# 2006-01-05             0.000000          214.910143          0.000000
#
#             potential_evaporation      pressure  shortwave_radiation  \
# Date
# 2006-01-01               0.044990  71408.170160            95.234192
# 2006-01-02               0.013663  70799.285724            93.932771
# 2006-01-03               0.030093  71724.799553           101.167170
# 2006-01-04               0.016272  72808.304958           101.368610
# 2006-01-05               0.033974  73429.441947           112.546583
#
#             specific_humidity  temperature  total_precipitation    wind_u  \
# Date
# 2006-01-01           0.002439    -7.561317             0.563703  2.807882
# 2006-01-02           0.004772    -0.944478             4.532128  4.467674
# 2006-01-03           0.002966    -6.371842             0.575387  4.247262
# 2006-01-04           0.003240    -3.462835             0.002358  1.485389
# 2006-01-05           0.002849     1.320337             0.000000 -0.779809
#
#               wind_v
# Date
# 2006-01-01  5.710911
# 2006-01-02  8.864378
# 2006-01-03  3.778855
# 2006-01-04  1.450410
# 2006-01-05  3.417216
# Index(['convective_fraction', 'longwave_radiation', 'potential_energy',
#        'potential_evaporation', 'pressure', 'shortwave_radiation',
#        'specific_humidity', 'temperature', 'total_precipitation', 'wind_u',
#        'wind_v'],
#       dtype='str')
# Index(['convective_fraction', 'longwave_radiation', 'potential_energy',
#        'potential_evaporation', 'pressure', 'shortwave_radiation',
#        'specific_humidity', 'temperature', 'total_precipitation', 'wind_u',
#        'wind_v'],
#       dtype='str')
# Index(['convective_fraction', 'longwave_radiation', 'potential_energy',
#        'potential_evaporation', 'pressure', 'shortwave_radiation',
#        'specific_humidity', 'temperature', 'total_precipitation', 'wind_u',
#        'wind_v'],
#       dtype='str')

# %%
tmp = Daily_NLDAS_df.reset_index()
print(tmp.columns)
print(tmp.head())
# Out:
# Index(['Date', 'convective_fraction', 'longwave_radiation', 'potential_energy',
#        'potential_evaporation', 'pressure', 'shortwave_radiation',
#        'specific_humidity', 'temperature', 'total_precipitation', 'wind_u',
#        'wind_v'],
#       dtype='str')
#         Date  convective_fraction  longwave_radiation  potential_energy  \
# 0 2006-01-01             0.005192          199.833836          1.508087
# 1 2006-01-02             0.051767          264.132482         33.055034
# 2 2006-01-03             0.016707          214.292827          9.209950
# 3 2006-01-04             0.000000          226.581243          0.000000
# 4 2006-01-05             0.000000          214.910143          0.000000
#
#    potential_evaporation      pressure  shortwave_radiation  \
# 0               0.044990  71408.170160            95.234192
# 1               0.013663  70799.285724            93.932771
# 2               0.030093  71724.799553           101.167170
# 3               0.016272  72808.304958           101.368610
# 4               0.033974  73429.441947           112.546583
#
#    specific_humidity  temperature  total_precipitation    wind_u    wind_v
# 0           0.002439    -7.561317             0.563703  2.807882  5.710911
# 1           0.004772    -0.944478             4.532128  4.467674  8.864378
# 2           0.002966    -6.371842             0.575387  4.247262  3.778855
# 3           0.003240    -3.462835             0.002358  1.485389  1.450410
# 4           0.002849     1.320337             0.000000 -0.779809  3.417216

# %%
def fix_date(df):
    out = df.copy()

    if 'date' in out.columns:
        out['date'] = pd.to_datetime(out['date'])
        return out

    out = out.reset_index()

    # if no explicit date column, assume first column is the date-like one
    first_col = out.columns[0]
    out = out.rename(columns={first_col: 'date'})
    out['date'] = pd.to_datetime(out['date'])

    return out

d1 = fix_date(Daily_NLDAS_df)
d2 = fix_date(Daily_NLDAS_df_2)
d3 = fix_date(Daily_NLDAS_df_3)

print(d1.columns)
print(d1.head())
# Out:
# Index(['date', 'convective_fraction', 'longwave_radiation', 'potential_energy',
#        'potential_evaporation', 'pressure', 'shortwave_radiation',
#        'specific_humidity', 'temperature', 'total_precipitation', 'wind_u',
#        'wind_v'],
#       dtype='str')
#         date  convective_fraction  longwave_radiation  potential_energy  \
# 0 2006-01-01             0.005192          199.833836          1.508087
# 1 2006-01-02             0.051767          264.132482         33.055034
# 2 2006-01-03             0.016707          214.292827          9.209950
# 3 2006-01-04             0.000000          226.581243          0.000000
# 4 2006-01-05             0.000000          214.910143          0.000000
#
#    potential_evaporation      pressure  shortwave_radiation  \
# 0               0.044990  71408.170160            95.234192
# 1               0.013663  70799.285724            93.932771
# 2               0.030093  71724.799553           101.167170
# 3               0.016272  72808.304958           101.368610
# 4               0.033974  73429.441947           112.546583
#
#    specific_humidity  temperature  total_precipitation    wind_u    wind_v
# 0           0.002439    -7.561317             0.563703  2.807882  5.710911
# 1           0.004772    -0.944478             4.532128  4.467674  8.864378
# 2           0.002966    -6.371842             0.575387  4.247262  3.778855
# 3           0.003240    -3.462835             0.002358  1.485389  1.450410
# 4           0.002849     1.320337             0.000000 -0.779809  3.417216

# %%
Daily_NLDAS_all = pd.concat([d1, d2, d3], ignore_index=True)
Daily_NLDAS_all = Daily_NLDAS_all.sort_values('date')

met_df_2019 = Daily_NLDAS_all[
    (Daily_NLDAS_all['date'] >= '2018-10-01') &
    (Daily_NLDAS_all['date'] <= '2019-09-30')
].copy()

print(met_df_2019.shape)
print(met_df_2019[['date', 'longwave_radiation', 'shortwave_radiation']].head())
# Out:
# (365, 12)
#            date  longwave_radiation  shortwave_radiation
# 4656 2018-10-01          241.029577           207.139162
# 4657 2018-10-02          256.625139           175.332732
# 4658 2018-10-03          273.616041           136.324320
# 4659 2018-10-04          267.482505           176.996055
# 4660 2018-10-05          218.407955           197.764840

# %%
plt.figure(figsize=(10,5))
plt.plot(met_df_2019['date'], met_df_2019['shortwave_radiation'], label='SW')
plt.plot(met_df_2019['date'], met_df_2019['longwave_radiation'], label='LW')
plt.legend()
plt.show()

# %% [markdown]
# ### Lets look at temperature

# %%
met_df_2019.columns
# Out:
# Index(['convective_fraction', 'longwave_radiation', 'potential_energy',
#        'potential_evaporation', 'pressure', 'shortwave_radiation',
#        'specific_humidity', 'temperature', 'total_precipitation', 'wind_u',
#        'wind_v'],
#       dtype='str')

# %%
fig, ax1 = plt.subplots(figsize=(6, 6))

ax1.set_xlabel('Date', fontsize=12)
ax1.set_ylabel('Temperature (°C)', color='darkorange', fontsize=12, fontweight='bold')
ax1.plot(met_df_2019['date'], met_df_2019['temperature'], linewidth=2, label='Daily Mean Temperature', color='red')
ax1.tick_params(axis='y', labelcolor='darkorange')
ax1.grid(True, alpha=0.3)

ax1.legend()

plt.title(f"Temperature for water year 2019 in the Basin \n Upstream of USGS gage: {usgs_gage_id}", fontsize=14, pad=15)
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Precipitation and temperature
#
# Use a dual y-axies to plot both on the same plot.
#
# What insights can we make about the type of precipitation?

# %%
def align_yaxis(ax1, ax2):
    """Align zeros of the two axes by adjusting their limits."""
    # Get current limits
    y1_min, y1_max = ax1.get_ylim()
    y2_min, y2_max = ax2.get_ylim()

    # Calculate the ratio of the zero point relative to the total range
    # Example: If zero is exactly in the middle, ratio = 0.5
    y1_ratio = -y1_min / (y1_max - y1_min)
    y2_ratio = -y2_min / (y2_max - y2_min)

    # Adjust the axis with the smaller ratio to match the larger one
    if y1_ratio < y2_ratio:
        ax1.set_ylim(bottom=-y1_max * y2_ratio / (1 - y2_ratio))
    else:
        ax2.set_ylim(bottom=-y2_max * y1_ratio / (1 - y1_ratio))

# %%
#make the plot
fig, ax1 = plt.subplots(figsize=(6, 6))

# --- Primary Y-axis: SWE_cm ---
ax1.set_xlabel('Date', fontsize=12)
ax1.set_ylabel('Temperature (°C)', color='orange', fontsize=12, fontweight='bold')
ax1.plot(met_df_2019.index, met_df_2019['temperature'], linewidth=2, label = 'Daily Mean Temperature', color='orange')
#ax1.plot(met_df_2019.index, met_df_2019['prcp_mm_day'], linewidth=2, label = 'Daily Precipitation', color='blue')
ax1.tick_params(axis='y', labelcolor='orange')
#make secondary y-axis for precipitation
ax2 = ax1.twinx()
ax2.plot(met_df_2019.index, met_df_2019['total_precipitation'], linewidth=2, label = 'Daily Precipitation', color='blue')
ax2.set_ylabel('Precipitation (mm)', color='blue', fontsize=12)
ax1.grid(True, alpha=0.3)
align_yaxis(ax1, ax2)

#Ask both axes for their handles and labels
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()

#Combine them and create one legend
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')


# Title and Layout
plt.title(f"Precipitation and Temperature for water year 2019 in the Basin \n Upstream of USGS gage: {usgs_gage_id}", fontsize=14, pad=15)
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Plot wind
#
# wind_u (Zonal Wind): Represents the east-west component. A positive value indicates wind blowing toward the east (from the west).
#
# wind_v (Meridional Wind): Represents the north-south component. A positive value indicates wind blowing toward the north (from the south)

# %%
met_df_2019.columns
# Out:
# Index(['convective_fraction', 'longwave_radiation', 'potential_energy',
#        'potential_evaporation', 'pressure', 'shortwave_radiation',
#        'specific_humidity', 'temperature', 'total_precipitation', 'wind_u',
#        'wind_v'],
#       dtype='str')

# %%
#make the plot
fig, ax1 = plt.subplots(figsize=(6, 6))

# --- Primary Y-axis: SWE_cm ---
ax1.set_xlabel('Date', fontsize=12)
ax1.set_ylabel('Wind Speed (m/s)', color='black', fontsize=12, fontweight='bold')
ax1.plot(met_df_2019.index, met_df_2019['wind_u'], linewidth=2, label = 'Zonal Wind Speed', color='blue')
ax1.plot(met_df_2019.index, met_df_2019['wind_v'], linewidth=2, label = 'Meridional Wind Speed', color='green')
ax1.tick_params(axis='y', labelcolor='black')
ax1.grid(True, alpha=0.3)

#show a legend
ax1.legend()

# Title and Layout
plt.title(f"Wind Speed for water year 2019 in the Basin \n Upstream of USGS gage: {usgs_gage_id}", fontsize=14, pad=15)
fig.tight_layout()
plt.show()

# %% [markdown]
# ### save the data for future use!

# %%
#save the cleaned dataframe to a csv file
# Use the getData module to retrieve data 
OutputFolder = 'files/NLDAS'
if not os.path.exists(OutputFolder):
    os.makedirs(OutputFolder)
Daily_NLDAS_df.to_csv(f'{OutputFolder}/NLDAS_{usgs_gage_id}.csv')
